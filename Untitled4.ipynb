# %% [markdown]
# <a href="https://colab.research.google.com/github/kommagoni99/AI-Face-Recognition-Attendance-Identity-Verification-System/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install deepface opencv-python matplotlib pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.2/169.2 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.1/197.1 kB 17.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 39.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 59.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 3.7 MB/s eta 0:00:00
# ...

# %%
# ==========================================================
# AI FACE RECOGNITION ATTENDANCE SYSTEM
# ==========================================================

import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from deepface import DeepFace
from datetime import datetime

# ----------------------------------------------------------
# 1. CREATE DATABASE FOLDER
# ----------------------------------------------------------

db_path = "face_database"
if not os.path.exists(db_path):
    os.makedirs(db_path)

print("Upload student images into 'face_database' folder before running recognition.")

# ----------------------------------------------------------
# 2. ATTENDANCE FILE
# ----------------------------------------------------------

attendance_file = "attendance_log.csv"

if not os.path.exists(attendance_file):
    df = pd.DataFrame(columns=["Name", "Date", "Time"])
    df.to_csv(attendance_file, index=False)

# ----------------------------------------------------------
# 3. FACE RECOGNITION FUNCTION
# ----------------------------------------------------------

def recognize_face(img_path):
    try:
        result = DeepFace.find(
            img_path=img_path,
            db_path=db_path,
            enforce_detection=False
        )

        if len(result[0]) > 0:
            identity = result[0]["identity"][0]
            name = identity.split("/")[-1].split(".")[0]
            return name
        else:
            return "Unknown"
    except:
        return "Unknown"

# ----------------------------------------------------------
# 4. LOG ATTENDANCE
# ----------------------------------------------------------

def mark_attendance(name):
    now = datetime.now()
    date = now.strftime("%Y-%m-%d")
    time = now.strftime("%H:%M:%S")

    df = pd.read_csv(attendance_file)

    if not ((df["Name"] == name) & (df["Date"] == date)).any():
        new_entry = pd.DataFrame([[name, date, time]], columns=["Name", "Date", "Time"])
        df = pd.concat([df, new_entry])
        df.to_csv(attendance_file, index=False)
        print(f"Attendance marked for {name}")
    else:
        print(f"{name} already marked today.")

# ----------------------------------------------------------
# 5. LIVE IMAGE UPLOAD FOR RECOGNITION
# ----------------------------------------------------------

from google.colab import files

print("\nUpload an image to verify identity:")
uploaded = files.upload()

for file_name in uploaded.keys():
    name = recognize_face(file_name)
    print("Recognized:", name)

    if name != "Unknown":
        mark_attendance(name)

# ----------------------------------------------------------
# 6. SHOW ATTENDANCE RECORD
# ----------------------------------------------------------

df = pd.read_csv(attendance_file)
print("\nAttendance Log:")
print(df)

# ----------------------------------------------------------
# 7. ATTENDANCE VISUALIZATION
# ----------------------------------------------------------

if len(df) > 0:
    plt.figure(figsize=(8,5))
    df["Name"].value_counts().plot(kind="bar")
    plt.title("Attendance Frequency")
    plt.ylabel("Count")
    plt.show()
# Out:
# 26-02-24 04:46:01 - Directory /root/.deepface has been created
# 26-02-24 04:46:01 - Directory /root/.deepface/weights has been created
# Upload student images into 'face_database' folder before running recognition.
#
# Upload an image to verify identity:
#      <input type="file" id="files-a9e422bd-3727-4bed-97b2-d3b4b34909b8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a9e422bd-3727-4bed-97b2-d3b4b34909b8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# ...
